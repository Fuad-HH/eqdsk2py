# %%
import gedsk
import matplotlib.pyplot as plt


import numpy as np

# %%
# read in the data
filename = r"D:\Codes\AllSamples\N-g127975.00430\g127975.00430"
data = gedsk.read_gedsk(filename)

# %%
xlims, ylims = gedsk.get_wall_points(filename)

# %%
# plot the xlims and ylims as points and connect them with line
plt.plot(xlims, ylims, 'o-', markersize=2, color='red')
# equal aspect ratio
plt.gca().set_aspect('equal', adjustable='box')
plt.show()
