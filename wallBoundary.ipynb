# %%
import gedsk
import matplotlib.pyplot as plt

# %%
# read in the data
filename = r"D:\Codes\AllSamples\N-g127975.00430\g127975.00430"
data = gedsk.read_gedsk(filename)

# %%
# get r and z of the boundary
R_bdry = data['rbdry']
Z_bdry = data['zbdry']

# %%
R_bdry.max(), R_bdry.min(), Z_bdry.max(), Z_bdry.min()
# Out:
# (1.45160397, 0.257154516, 1.28665273, -1.44337102)

# %%
psi = gedsk.get_psi(data)

# %%
# plot the boundary
plt.plot(R_bdry, Z_bdry)
plt.axis('equal')
plt.show()
